# %% [markdown]
# <a href="https://colab.research.google.com/github/louvair/Python/blob/main/Dropsul/Base_Drop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# # Este código gera um arquivo csv com dados fictícios para projeto de ETL
# ```
#
# # Nova seção

# %%
import csv
from faker import Faker
import random
from datetime import datetime, timedelta

fake = Faker('pt_BR')  # Configurando o Faker para gerar dados em português do Brasil

# Função para gerar registros
def gerar_registro(codigo, numero_pedido):
    nome_produto = fake.random_element(elements=(
        'Creme Facial',
        'Escova para Cães',
        'Chaleira Elétrica',
        'Panela Antiaderente',
        'Ração para Cães',
        'Chaleira Elétrica',
        'Shampoo',
        'Mouse Gamer sem Fio',
        'Quebra-Cabeça 500pcs',
        'Fone de Ouvido Sem Fio M3',
        'Smartphone Samsung Galaxy S23 Ultra',
        'Cadeira gamer Razer Iskur',
        'Roupa de cachorro',
        'Fogão de embutir Brastemp',
        'Brinquedo Lego Star Wars',
        'Liquidificador Oster',
        'Coleira GPS para Pet',
        'Notebook Dell',
        'Boneca Barbie'
        )
    )
    categoria = {
        'Smartphone Samsung Galaxy S23 Ultra': 'Eletrônicos',
        'Creme Facial': 'Saúde e Beleza',
        'Escova para Cães': 'Pets',
        'Chaleira Elétrica': 'Casa e Cozinha',
        'Panela Antiaderente': 'Casa e Cozinha',
        'Ração para Cães': 'Pets',
        'Chaleira Elétrica': 'Casa e Cozinha',
        'Shampoo': 'Saúde e Beleza',
        'Mouse Gamer sem Fio': 'Eletrônicos',
        'Quebra-Cabeça 500pcs': 'Brinquedos',
        'Fone de Ouvido Sem Fio M3': 'Eletrônicos',
        'Cadeira gamer Razer Iskur': 'Casa e Cozinha',
        'Roupa de cachorro': 'Pets',
        'Fogão de embutir Brastemp': 'Casa e Cozinha',
        'Brinquedo Lego Star Wars': 'Brinquedos',
        'Liquidificador Oster': 'Casa e Cozinha',
        'Coleira GPS para Pet': 'Pets',
        'Notebook Dell': 'Eletrônicos',
        'Boneca Barbie': 'Brinquedos'
    }[nome_produto]

    setor = fake.random_element(elements=('Oferta da Semana', 'Lançamentos', 'Promoções', 'Nenhum'))
    data_compra = fake.date_between(start_date='-30d', end_date='today')
    valor_compra = round(random.uniform(10, 250), 2)
    quantidade_produto = random.randint(1, 5)
    tipo_pagamento = fake.random_element(elements=('A vista', 'Crédito'))
    forma_pagamento = fake.random_element(elements=('Visa', 'Mastercard', 'Elo', 'American Express', 'Boleto', 'Pix'))
    nome_cliente = fake.name()
    endereco_cliente = fake.address()
    cidade_cliente = fake.city()
    estado_cliente = fake.random_element(elements=(
        'AL',
        'AM',
        'AP',
        'BA',
        'CE',
        'DF',
        'ES',
        'GO',
        'MA',
        'MG',
        'MS',
        'MT',
        'PA',
        'PB',
        'PE',
        'PI',
        'PR',
        'RJ',
        'RN',
        'RO',
        'RR',
        'RS',
        'SC',
        'SE',
        'SP',
        'TO'
        )
    )
    cidade_cliente = {
        'RS': 'Porto Alegre',
        'RS': 'Gramado',
        'SP': 'São Paulo',
        'RJ': 'Rio de Janeiro',
        'MG': 'Belo Horizonte',
        'RS': 'Porto Alegre',
        'DF': 'Brasília',
        'BA': 'Salvador',
        'CE': 'Fortaleza',
        'PE': 'Recife',
        'PR': 'Curitiba',
        'AM': 'Manaus',
        'PA': 'Belém',
        'GO': 'Goiânia',
        'MT': 'Cuiabá',
        'SC': 'Florianópolis',
        'ES': 'Vitória',
        'MS': 'Campo Grande',
        'RN': 'Natal',
        'PI': 'Teresina',
        'PB': 'João Pessoa',
        'SE': 'Aracaju',
        'AL': 'Maceió',
        'MA': 'São Luís',
        'TO': 'Palmas',
        'RR': 'Boa Vista',
        'AC': 'Rio Branco',
        'RO': 'Porto Velho',
        'MT': 'Cuiabá',
        'RJ': 'Niterói',
        'SP': 'Santo André',
        'SP': 'Osasco',
        'SP': 'Sorocaba',
        'SP': 'Ribeirão Preto',
        'SP': 'Campinas',
        'SP': 'São Bernardo do Campo',
        'SP': 'Jundiaí',
        'SP': 'São José dos Campos',
        'MG': 'Uberlândia',
        'MG': 'Contagem',
        'BA': 'Feira de Santana',
        'MG': 'Juiz de Fora',
        'PE': 'Paulista',
        'MG': 'Betim',
        'SP': 'Mauá',
        'SP': 'Mogi das Cruzes',
        'SP': 'São José do Rio Preto',
        'SC': 'Joinville',
        'PA': 'Ananindeua',
        'RS': 'Caxias do Sul',
        'SP': 'Bauru',
        'RJ': 'Campos dos Goytacazes',
        'GO': 'Aparecida de Goiânia',
        'RJ': 'São João de Meriti',
        'RJ': 'Niterói',
        'ES': 'Serra',
        'ES': 'Vila Velha',
        'RJ': 'Duque de Caxias',
        'PE': 'Jaboatão dos Guararapes',
        'SP': 'Osasco',
        'SP': 'São José do Rio Preto',
        'MG': 'Uberaba',
        'RS': 'Canoas',
        'SP': 'Piracicaba',
        'SP': 'Franca',
        'SP': 'São Vicente',
        'RS': 'Pelotas',
        'PR': 'Londrina',
        'SP': 'Itaquaquecetuba',
        'AP': 'Macapá',
        'SC': 'Florianópolis',
        'SE': 'Nossa Senhora do Socorro',
        'MT': 'Cuiabá',
        'MA': 'Imperatriz',
        'PA': 'Marabá',
        'PE': 'Petrolina',
        'CE': 'Caucaia',
        'RS': 'Rio Grande',
        'BA': 'Vitória da Conquista',
        'SP': 'Carapicuíba',
        'BA': 'Porto Seguro',
        'CE': 'Terêncio',
        'SP': 'Jundiaí',
        'RS': 'Pelotas',
        'SP': 'Barueri',
        'SP': 'Franca',
        'SP': 'Ribeirão Pires',
        'SP': 'Diadema',
        'SP': 'Taboão da Serra',
        'SP': 'Barretos',
        'BA': 'Itabuna',
        'SP': 'Taubaté',
        'MG': 'Santa Luzia',
        'SP': 'Praia Grande',
        'MG': 'Governador Valadares',
        'SP': 'Marília',
        'MG': 'Sete Lagoas',
        'GO': 'Luziânia',
        'MS': 'Dourados'
    }[estado_cliente]

    email_cliente = fake.email()
    whatsapp_cliente = fake.phone_number()

    return [codigo, numero_pedido, nome_produto, categoria, setor, data_compra, valor_compra,
            quantidade_produto, tipo_pagamento, forma_pagamento, nome_cliente, endereco_cliente,
            cidade_cliente, estado_cliente, email_cliente, whatsapp_cliente]

# Configuração do CSV
cabecalho = ['Código', 'Número do Pedido', 'Nome do Produto', 'Categoria', 'Setor', 'Data da Compra',
             'Valor da Compra', 'Quantidade de Produto', 'Tipo de Pagamento', 'Forma de Pagamento',
             'Nome do Cliente', 'Endereço do Cliente', 'Cidade do Cliente', 'Estado do Cliente',
             'E-mail do Cliente', 'Whatsapp do Cliente']

# Gerando os dados e escrevendo no arquivo CSV
with open('registros_dropshipping.csv', 'w', newline='', encoding='utf-8') as arquivo_csv:
    escritor_csv = csv.writer(arquivo_csv, delimiter=';')
    escritor_csv.writerow(cabecalho)

    for i in range(1, 3001):
        registro = gerar_registro(i, random.randint(100, 1000))
        escritor_csv.writerow(registro)

print("Arquivo CSV gerado com sucesso.")
# Out:
# Arquivo CSV gerado com sucesso.

# %%
import csv

# Lista de cidades brasileiras com seus estados abreviados
cidades_brasil = [
    ('São Paulo', 'SP'),
    ('Rio de Janeiro', 'RJ'),
    ('Belo Horizonte', 'MG'),
    ('Porto Alegre', 'RS'),
    ('Brasília', 'DF'),
    ('Salvador', 'BA'),
    ('Fortaleza', 'CE'),
    ('Recife', 'PE'),
    ('Curitiba', 'PR'),
    ('Manaus', 'AM'),
    ('Belém', 'PA'),
    ('Goiânia', 'GO'),
    ('Cuiabá', 'MT'),
    ('Florianópolis', 'SC'),
    ('Vitória', 'ES'),
    ('Campo Grande', 'MS'),
    ('Natal', 'RN'),
    ('Teresina', 'PI'),
    ('João Pessoa', 'PB'),
    ('Aracaju', 'SE'),
    ('Maceió', 'AL'),
    ('São Luís', 'MA'),
    ('Palmas', 'TO'),
    ('Boa Vista', 'RR'),
    ('Rio Branco', 'AC'),
    ('Porto Velho', 'RO'),
    ('Cuiabá', 'MT'),
    ('Niterói', 'RJ'),
    ('Santo André', 'SP'),
    ('Osasco', 'SP'),
    ('Sorocaba', 'SP'),
    ('Ribeirão Preto', 'SP'),
    ('Campinas', 'SP'),
    ('São Bernardo do Campo', 'SP'),
    ('Jundiaí', 'SP'),
    ('São José dos Campos', 'SP'),
    ('Uberlândia', 'MG'),
    ('Contagem', 'MG'),
    ('Feira de Santana', 'BA'),
    ('Juiz de Fora', 'MG'),
    ('Paulista', 'PE'),
    ('Betim', 'MG'),
    ('Mauá', 'SP'),
    ('Mogi das Cruzes', 'SP'),
    ('São José do Rio Preto', 'SP'),
    ('Joinville', 'SC'),
    ('Ananindeua', 'PA'),
    ('Caxias do Sul', 'RS'),
    ('Bauru', 'SP'),
    ('Campos dos Goytacazes', 'RJ'),
    ('Aparecida de Goiânia', 'GO'),
    ('São João de Meriti', 'RJ'),
    ('Niterói', 'RJ'),
    ('Serra', 'ES'),
    ('Vila Velha', 'ES'),
    ('Duque de Caxias', 'RJ'),
    ('Jaboatão dos Guararapes', 'PE'),
    ('Osasco', 'SP'),
    ('São José do Rio Preto', 'SP'),
    ('Uberaba', 'MG'),
    ('Canoas', 'RS'),
    ('Piracicaba', 'SP'),
    ('Franca', 'SP'),
    ('São Vicente', 'SP'),
    ('Pelotas', 'RS'),
    ('Londrina', 'PR'),
    ('Itaquaquecetuba', 'SP'),
    ('Macapá', 'AP'),
    ('Florianópolis', 'SC'),
    ('Nossa Senhora do Socorro', 'SE'),
    ('Cuiabá', 'MT'),
    ('Imperatriz', 'MA'),
    ('Marabá', 'PA'),
    ('Petrolina', 'PE'),
    ('Caucaia', 'CE'),
    ('Rio Grande', 'RS'),
    ('Vitória da Conquista', 'BA'),
    ('Carapicuíba', 'SP'),
    ('Porto Seguro', 'BA'),
    ('Terêncio', 'CE'),
    ('Jundiaí', 'SP'),
    ('Pelotas', 'RS'),
    ('Barueri', 'SP'),
    ('Franca', 'SP'),
    ('Ribeirão Pires', 'SP'),
    ('Diadema', 'SP'),
    ('Taboão da Serra', 'SP'),
    ('Barretos', 'SP'),
    ('Itabuna', 'BA'),
    ('Taubaté', 'SP'),
    ('Santa Luzia', 'MG'),
    ('Praia Grande', 'SP'),
    ('Governador Valadares', 'MG'),
    ('Marília', 'SP'),
    ('Sete Lagoas', 'MG'),
    ('Luziânia', 'GO'),
    ('Dourados', 'MS'),
]

# Configuração do CSV
cabecalho = ['Cidade', 'Estado']

# Gerando os dados e escrevendo no arquivo CSV
with open('cidades_brasil.csv', 'w', newline='', encoding='utf-8') as arquivo_csv:
    escritor_csv = csv.writer(arquivo_csv, delimiter=';')
    escritor_csv.writerow(cabecalho)

    for cidade, estado in cidades_brasil:
        escritor_csv.writerow([cidade, estado])

print("Arquivo CSV com cidades do Brasil gerado com sucesso.")
# Out:
# Arquivo CSV com cidades do Brasil gerado com sucesso.
